# %%
import pandas as pd
import json

# %%
with open('../data/event_history.json') as fin:
    raw = json.loads(fin.read())

# %%
raw.keys()
# Out:
# dict_keys(['Records'])

# %%
data = pd.DataFrame.from_dict(raw['Records'])

# %%
data.shape
# Out:
# (28990, 27)

# %%
data.head()
# Out:
#   eventVersion                                       userIdentity  \
# 0         1.08  {'type': 'AssumedRole', 'principalId': 'AROA2K...
# 1         1.08  {'type': 'AssumedRole', 'principalId': 'AROA2K...
# 2         1.08  {'type': 'AssumedRole', 'principalId': 'AROA2K...
# 3         1.08  {'type': 'AWSService', 'invokedBy': 'securityh...
# 4         1.08  {'type': 'AssumedRole', 'principalId': 'AROA2K...
#
#               eventTime           eventSource            eventName  \
# 0  2022-01-25T01:59:55Z  states.amazonaws.com  GetExecutionHistory
# 1  2022-01-25T01:59:45Z  states.amazonaws.com  GetExecutionHistory
# 2  2022-01-25T01:59:44Z  config.amazonaws.com       PutEvaluations
# 3  2022-01-25T01:59:44Z     sts.amazonaws.com           AssumeRole
# 4  2022-01-25T01:59:43Z     ec2.amazonaws.com     DescribeFlowLogs
#
#         awsRegion            sourceIPAddress  \
# 0  ap-southeast-2            163.116.192.118
# 1  ap-southeast-2            163.116.192.118
# 2  ap-southeast-2  securityhub.amazonaws.com
# 3  ap-southeast-2  securityhub.amazonaws.com
# 4  ap-southeast-2               3.25.253.152
#
#                                            userAgent  \
# 0                              console.amazonaws.com
# 1                              console.amazonaws.com
# 2                          securityhub.amazonaws.com
# 3                          securityhub.amazonaws.com
# 4  Boto3/1.16.10 Python/3.8.11 Linux/4.14.252-207...
#
#                                    requestParameters  \
# 0  {'executionArn': 'arn:aws:states:ap-southeast-...
# 1  {'executionArn': 'arn:aws:states:ap-southeast-...
# 2  {'resultToken': 'eyJlbmNyeXB0ZWREYXRhIjpbLTEyN...
# 3  {'roleArn': 'arn:aws:iam::709033477802:role/aw...
# 4  {'DescribeFlowLogsRequest': {'Filter': {'Value...
#
#                                     responseElements  ...  \
# 0                                               None  ...
# 1                                               None  ...
# 2                                               None  ...
# 3  {'credentials': {'accessKeyId': 'ASIA2KFNQI2VP...  ...
# 4                                               None  ...
#
#   sessionCredentialFromConsole  \
# 0                         true
# 1                         true
# 2                          NaN
# 3                          NaN
# 4                          NaN
#
#                                  additionalEventData  \
# 0                                                NaN
# 1                                                NaN
# 2  {'configRuleName': 'securityhub-vpc-sg-restric...
# 3                                                NaN
# 4                                                NaN
#
#                                            resources  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  [{'accountId': '709033477802', 'type': 'AWS::I...
# 4                                                NaN
#
#                           sharedEventID  tlsDetails errorCode errorMessage  \
# 0                                   NaN         NaN       NaN          NaN
# 1                                   NaN         NaN       NaN          NaN
# 2                                   NaN         NaN       NaN          NaN
# 3  b0d454a3-5fa7-4863-937a-b642058ef1be         NaN       NaN          NaN
# 4                                   NaN         NaN       NaN          NaN
#
#   apiVersion vpcEndpointId serviceEventDetails
# 0        NaN           NaN                 NaN
# 1        NaN           NaN                 NaN
# 2        NaN           NaN                 NaN
# 3        NaN           NaN                 NaN
# 4        NaN           NaN                 NaN
#
# [5 rows x 27 columns]

# %%
data['userIdentity'].iloc[0]
# Out:
# {'type': 'AssumedRole',
#  'principalId': 'AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#  'arn': 'arn:aws:sts::709033477802:assumed-role/Dev-Mlops-KL/jiaxi.li@vodafone.com.au',
#  'accountId': '709033477802',
#  'accessKeyId': 'ASIA2KFNQI2VFUIUJYMV',
#  'sessionContext': {'sessionIssuer': {'type': 'Role',
#    'principalId': 'AROA2KFNQI2VJ2RJJK6SI',
#    'arn': 'arn:aws:iam::709033477802:role/Dev-Mlops-KL',
#    'accountId': '709033477802',
#    'userName': 'Dev-Mlops-KL'},
#   'webIdFederationData': {},
#   'attributes': {'creationDate': '2022-01-24T22:00:10Z',
#    'mfaAuthenticated': 'false'}}}

# %%
def parse_node_from_user_identity(user_identity):
    try:
        typ = user_identity['type']

        if typ == 'AssumedRole':
            principal = user_identity['principalId']
            id_arn = user_identity['sessionContext']['sessionIssuer']['arn']
#             return edge_type, (principal, id_arn)
            return principal, typ

        elif typ == 'AWSService':
            invoke = user_identity['invokedBy']
#             return edge_type, invoke
            return invoke, typ

        elif typ == 'AWSAccount':
            invoke = user_identity['invokedBy']
            principal = user_identity['principalId']
#             return edge_type, (principal, invoke)
            return principal, typ
            
    except Exception as e:
        print(e)
        invoke = user_identity['invokedBy']
        return 'Account', invoke
    return None, None

# %%
def parse_node_from_request_parameter(request):
    try:
        arns = [request[k] for k in request.keys() if 'arn' in k.lower()]
        return arns
    except Exception as e:
#         print(e)
        return None

# %%
data['p_request'] = data['requestParameters'].apply(lambda x: parse_node_from_request_parameter(x))
data[data['p_request'].notna()][
    data[data['p_request'].notna()]['p_request'].apply(lambda x: len(x) > 1)
]['p_request'].iloc[0]
# Out:
# ['arn:aws:states:ap-southeast-2:709033477802:stateMachine:kl-prod-bi-analy-footfall-AdelaideFootfallSFN',
#  'arn:aws:iam::709033477802:role/kl-prod-bi-analy-ml-pltf-stepfunction-exec-role']

# %%
data['requestParameters']
# Out:
# 0        {'executionArn': 'arn:aws:states:ap-southeast-...
# 1        {'executionArn': 'arn:aws:states:ap-southeast-...
# 2        {'resultToken': 'eyJlbmNyeXB0ZWREYXRhIjpbLTEyN...
# 3        {'roleArn': 'arn:aws:iam::709033477802:role/aw...
# 4        {'DescribeFlowLogsRequest': {'Filter': {'Value...
#                                ...
# 28985    {'roleArn': 'arn:aws:iam::709033477802:role/St...
# 28986    {'webACLId': '999d4219-b940-4ab1-8bba-8f5b9a83...
# 28987    {'roleArn': 'arn:aws:iam::709033477802:role/aw...
# 28988    {'roleArn': 'arn:aws:iam::709033477802:role/aw...
# 28989    {'configRuleNames': ['FMManagedShieldConfigRul...
# Name: requestParameters, Length: 28990, dtype: object

# %%
data['p_identity'] = data['userIdentity'].apply(lambda x: parse_node_from_user_identity(x))
data[data['p_identity'].isna()]
# Out:
# 'type'
# 'type'
# 'type'
# Empty DataFrame
# Columns: [eventVersion, userIdentity, eventTime, eventSource, eventName, awsRegion, sourceIPAddress, userAgent, requestParameters, responseElements, requestID, eventID, readOnly, eventType, managementEvent, recipientAccountId, eventCategory, sessionCredentialFromConsole, additionalEventData, resources, sharedEventID, tlsDetails, errorCode, errorMessage, apiVersion, vpcEndpointId, serviceEventDetails, p_identity, p_request]
# Index: []
#
# [0 rows x 29 columns]

# %%
col_idx_map = dict(zip(data.columns.values, range(len(data.columns.values))))
col_idx_map
# Out:
# {'eventVersion': 0,
#  'userIdentity': 1,
#  'eventTime': 2,
#  'eventSource': 3,
#  'eventName': 4,
#  'awsRegion': 5,
#  'sourceIPAddress': 6,
#  'userAgent': 7,
#  'requestParameters': 8,
#  'responseElements': 9,
#  'requestID': 10,
#  'eventID': 11,
#  'readOnly': 12,
#  'eventType': 13,
#  'managementEvent': 14,
#  'recipientAccountId': 15,
#  'eventCategory': 16,
#  'sessionCredentialFromConsole': 17,
#  'additionalEventData': 18,
#  'resources': 19,
#  'sharedEventID': 20,
#  'tlsDetails': 21,
#  'errorCode': 22,
#  'errorMessage': 23,
#  'apiVersion': 24,
#  'vpcEndpointId': 25,
#  'serviceEventDetails': 26,
#  'p_identity': 27,
#  'p_request': 28}

# %%
def parse_edge_from_action(row):
    eventTime = row[col_idx_map['eventTime']]
    
    dst_type = row[col_idx_map['eventSource']]
    
    dst = row[col_idx_map['p_request']]
    if dst:
        dst = dst[0]

    edge_type = row[col_idx_map['eventName']]
    
    src, src_type = row[col_idx_map['p_identity']]
    
    return (src, src_type, dst, dst_type, edge_type)

# %%
data.loc[2]
# Out:
# eventVersion                                                                 1.08
# userIdentity                    {'type': 'AssumedRole', 'principalId': 'AROA2K...
# eventTime                                                    2022-01-25T01:59:44Z
# eventSource                                                  config.amazonaws.com
# eventName                                                          PutEvaluations
# awsRegion                                                          ap-southeast-2
# sourceIPAddress                                         securityhub.amazonaws.com
# userAgent                                               securityhub.amazonaws.com
# requestParameters               {'resultToken': 'eyJlbmNyeXB0ZWREYXRhIjpbLTEyN...
# responseElements                                                             None
# requestID                                    81b9e163-f6e7-4aef-b3c5-8450c20701f5
# eventID                                      a0b1dee9-62c4-4237-8f7f-6eeee09e9b6a
# readOnly                                                                    False
# eventType                                                              AwsApiCall
# managementEvent                                                              True
# recipientAccountId                                                   709033477802
# eventCategory                                                          Management
# sessionCredentialFromConsole                                                  NaN
# additionalEventData             {'configRuleName': 'securityhub-vpc-sg-restric...
# resources                                                                     NaN
# sharedEventID                                                                 NaN
# tlsDetails                                                                    NaN
# errorCode                                                                     NaN
# errorMessage                                                                  NaN
# apiVersion                                                                    NaN
# vpcEndpointId                                                                 NaN
# serviceEventDetails                                                           NaN
# p_identity                      (AROA2KFNQI2VIS4KBLKIC:SecurityHub-PutEvaluati...
# p_request                                                                      []
# edges                           (AROA2KFNQI2VIS4KBLKIC:SecurityHub-PutEvaluati...
# Name: 2, dtype: object

# %%
data['edges'] = data.apply(lambda x: parse_edge_from_action(x), axis=1)

# %%
data['edges'].values.tolist()
# Out:
# [('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   'arn:aws:states:ap-southeast-2:709033477802:execution:kl-prod-bi-analy-data-extract-network_ice:14af7be9-a64e-a960-d509-5fae65753a94_144e8ea0-9ec0-6795-620f-3b32e0edf669',
#   'states.amazonaws.com',
#   'GetExecutionHistory'),
#  ('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   'arn:aws:states:ap-southeast-2:709033477802:execution:kl-prod-bi-analy-data-extract-network_ice:14af7be9-a64e-a960-d509-5fae65753a94_144e8ea0-9ec0-6795-620f-3b32e0edf669',
#   'states.amazonaws.com',
#   'GetExecutionHistory'),
#  ('AROA2KFNQI2VIS4KBLKIC:SecurityHub-PutEvaluations',
#   'AssumedRole',
#   [],
#   'config.amazonaws.com',
#   'PutEvaluations'),
#  ('securityhub.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/aws-service-role/securityhub.amazonaws.com/AWSServiceRoleForSecurityHub',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeFlowLogs'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   [],
#   'config.amazonaws.com',
#   'PutEvaluations'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeVpcEndpoints'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   [],
#   'route53resolver.amazonaws.com',
#   'ListResolverQueryLogConfigAssociations'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   None,
#   'route53resolver.amazonaws.com',
#   'ListResolverQueryLogConfigs'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeSecurityGroups'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeVpcs'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeVpcs'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeVpcPeeringConnections'),
#  ('AROA2KFNQI2VABAX5A6Y4:StackSet-tpgt-resolverlogs-a533-VPCResolverChecker-8ozYsSdZK8Ak',
#   'AssumedRole',
#   'arn:aws:iam::709033477802:role/tpgt-config-service-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('config.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/tpgt-config-service-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('AROA2KFNQI2VOBXYK2K25:tpgt-vpc-flowlog-check',
#   'AssumedRole',
#   'arn:aws:iam::709033477802:role/tpgt-config-service-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   [],
#   'config.amazonaws.com',
#   'PutEvaluations'),
#  ('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetJobRuns'),
#  ('config.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/tpgt-config-service-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   [],
#   'config.amazonaws.com',
#   'PutEvaluations'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   [],
#   'config.amazonaws.com',
#   'PutEvaluations'),
#  ('config.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/tpgt-config-service-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   [],
#   'config.amazonaws.com',
#   'PutEvaluations'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   [],
#   'config.amazonaws.com',
#   'PutEvaluations'),
#  ('config.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/tpgt-config-service-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('config.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/tpgt-config-service-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   [],
#   'sagemaker.amazonaws.com',
#   'ListNotebookInstances'),
#  ('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   'arn:aws:states:ap-southeast-2:709033477802:execution:kl-prod-bi-analy-data-extract-network_ice:14af7be9-a64e-a960-d509-5fae65753a94_144e8ea0-9ec0-6795-620f-3b32e0edf669',
#   'states.amazonaws.com',
#   'GetExecutionHistory'),
#  ('logs.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/StackSet-tpgt-flowlogs-lo-FlowLogsSubscriptionRole-5QJS99X9108W',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('AROA2KFNQI2VALLEGEAQL:AWSConfig-Describe',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeSecurityGroups'),
#  ('AROA2KFNQI2VALLEGEAQL:AWSConfig-Describe',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeNetworkInterfaces'),
#  ('AROA2KFNQI2VALLEGEAQL:AWSConfig-Describe',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeVpcs'),
#  ('AROA2KFNQI2VALLEGEAQL:AWSConfig-Describe',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeSubnets'),
#  ('AROA2KFNQI2VALLEGEAQL:AWSConfig-Describe',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeNetworkInterfaces'),
#  ('config.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/tpgt-config-service-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('AROA2KFNQI2VALLEGEAQL:AWSConfig-Describe',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeNetworkInterfaces'),
#  ('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   'arn:aws:states:ap-southeast-2:709033477802:execution:kl-prod-bi-analy-data-extract-network_ice:14af7be9-a64e-a960-d509-5fae65753a94_144e8ea0-9ec0-6795-620f-3b32e0edf669',
#   'states.amazonaws.com',
#   'GetExecutionHistory'),
#  ('glue.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/kl-prod-bi-analy-data-extract-glue-extract-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   'arn:aws:states:ap-southeast-2:709033477802:execution:kl-prod-bi-analy-data-extract-network_ice:14af7be9-a64e-a960-d509-5fae65753a94_144e8ea0-9ec0-6795-620f-3b32e0edf669',
#   'states.amazonaws.com',
#   'GetExecutionHistory'),
#  ('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   'arn:aws:states:ap-southeast-2:709033477802:execution:kl-prod-bi-analy-data-extract-network_ice:14af7be9-a64e-a960-d509-5fae65753a94_144e8ea0-9ec0-6795-620f-3b32e0edf669',
#   'states.amazonaws.com',
#   'GetExecutionHistory'),
#  ('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   'arn:aws:states:ap-southeast-2:709033477802:execution:kl-prod-bi-analy-data-extract-network_ice:14af7be9-a64e-a960-d509-5fae65753a94_144e8ea0-9ec0-6795-620f-3b32e0edf669',
#   'states.amazonaws.com',
#   'GetExecutionHistory'),
#  ('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   [],
#   'sagemaker.amazonaws.com',
#   'ListNotebookInstances'),
#  ('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   'arn:aws:states:ap-southeast-2:709033477802:execution:kl-prod-bi-analy-data-extract-network_ice:14af7be9-a64e-a960-d509-5fae65753a94_144e8ea0-9ec0-6795-620f-3b32e0edf669',
#   'states.amazonaws.com',
#   'GetExecutionHistory'),
#  ('AROA2KFNQI2VLFR6ZN65C:kYAToKGjiAMchIixdScqOhjlWBHiSWPQ',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetJobRun'),
#  ('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   'arn:aws:states:ap-southeast-2:709033477802:execution:kl-prod-bi-analy-data-extract-network_ice:14af7be9-a64e-a960-d509-5fae65753a94_144e8ea0-9ec0-6795-620f-3b32e0edf669',
#   'states.amazonaws.com',
#   'GetExecutionHistory'),
#  ('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   'arn:aws:states:ap-southeast-2:709033477802:execution:kl-prod-bi-analy-data-extract-network_ice:14af7be9-a64e-a960-d509-5fae65753a94_144e8ea0-9ec0-6795-620f-3b32e0edf669',
#   'states.amazonaws.com',
#   'GetExecutionHistory'),
#  ('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   'arn:aws:states:ap-southeast-2:709033477802:execution:kl-prod-bi-analy-data-extract-network_ice:14af7be9-a64e-a960-d509-5fae65753a94_144e8ea0-9ec0-6795-620f-3b32e0edf669',
#   'states.amazonaws.com',
#   'GetExecutionHistory'),
#  ('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   'arn:aws:states:ap-southeast-2:709033477802:execution:kl-prod-bi-analy-data-extract-network_ice:14af7be9-a64e-a960-d509-5fae65753a94_144e8ea0-9ec0-6795-620f-3b32e0edf669',
#   'states.amazonaws.com',
#   'GetExecutionHistory'),
#  ('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   'arn:aws:states:ap-southeast-2:709033477802:execution:kl-prod-bi-analy-data-extract-network_ice:14af7be9-a64e-a960-d509-5fae65753a94_144e8ea0-9ec0-6795-620f-3b32e0edf669',
#   'states.amazonaws.com',
#   'GetExecutionHistory'),
#  ('AROA2KFNQI2VLFR6ZN65C:kYAToKGjiAMchIixdScqOhjlWBHiSWPQ',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetJobRun'),
#  ('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetJobRuns'),
#  ('AROA2KFNQI2VIS4KBLKIC:SecurityHub-PutEvaluations',
#   'AssumedRole',
#   [],
#   'config.amazonaws.com',
#   'PutEvaluations'),
#  ('securityhub.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/aws-service-role/securityhub.amazonaws.com/AWSServiceRoleForSecurityHub',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   [],
#   'sagemaker.amazonaws.com',
#   'ListNotebookInstances'),
#  ('config.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/tpgt-config-service-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   [],
#   'config.amazonaws.com',
#   'PutEvaluations'),
#  ('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   'arn:aws:states:ap-southeast-2:709033477802:execution:kl-prod-bi-analy-data-extract-network_ice:14af7be9-a64e-a960-d509-5fae65753a94_144e8ea0-9ec0-6795-620f-3b32e0edf669',
#   'states.amazonaws.com',
#   'GetExecutionHistory'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   [],
#   'config.amazonaws.com',
#   'PutEvaluations'),
#  ('AROA2KFNQI2VLFR6ZN65C:KhjWBoIWgdKtVxMxBFzqKhIYUEoPNTHa',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetJobRun'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeFlowLogs'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   None,
#   'route53resolver.amazonaws.com',
#   'ListResolverQueryLogConfigs'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeVpcPeeringConnections'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeVpcEndpoints'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeVpcs'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   [],
#   'route53resolver.amazonaws.com',
#   'ListResolverQueryLogConfigAssociations'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeSecurityGroups'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeVpcs'),
#  ('AROA2KFNQI2VABAX5A6Y4:StackSet-tpgt-resolverlogs-a533-VPCResolverChecker-8ozYsSdZK8Ak',
#   'AssumedRole',
#   'arn:aws:iam::709033477802:role/tpgt-config-service-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('AROA2KFNQI2VOBXYK2K25:tpgt-vpc-flowlog-check',
#   'AssumedRole',
#   'arn:aws:iam::709033477802:role/tpgt-config-service-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   [],
#   'config.amazonaws.com',
#   'PutEvaluations'),
#  ('config.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/tpgt-config-service-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DeleteNetworkInterface'),
#  ('AROA2KFNQI2VOG7475UEI:AWSFirewallManager',
#   'AssumedRole',
#   [],
#   'config.amazonaws.com',
#   'DescribeComplianceByConfigRule'),
#  ('config.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/tpgt-config-service-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DeleteNetworkInterface'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   [],
#   'config.amazonaws.com',
#   'PutEvaluations'),
#  ('config.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/tpgt-config-service-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   [],
#   'config.amazonaws.com',
#   'PutEvaluations'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   [],
#   'config.amazonaws.com',
#   'PutEvaluations'),
#  ('config.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/tpgt-config-service-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('glue.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/kl-prod-bi-analy-data-extract-glue-extract-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('glue.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/kl-prod-bi-analy-data-extract-glue-extract-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('AROA2KFNQI2VOG7475UEI:AWSFirewallManager',
#   'AssumedRole',
#   [],
#   'waf-regional.amazonaws.com',
#   'GetWebACL'),
#  ('fms.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/aws-service-role/fms.amazonaws.com/AWSServiceRoleForFMS',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('fms.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/aws-service-role/fms.amazonaws.com/AWSServiceRoleForFMS',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   'arn:aws:states:ap-southeast-2:709033477802:execution:kl-prod-bi-analy-data-extract-network_ice:14af7be9-a64e-a960-d509-5fae65753a94_144e8ea0-9ec0-6795-620f-3b32e0edf669',
#   'states.amazonaws.com',
#   'GetExecutionHistory'),
#  ('AROA2KFNQI2VALLEGEAQL:AWSConfig-Describe',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeSubnets'),
#  ('config.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/tpgt-config-service-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('AROA2KFNQI2VALLEGEAQL:AWSConfig-Describe',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeNetworkInterfaces'),
#  ('AROA2KFNQI2VALLEGEAQL:AWSConfig-Describe',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeNetworkInterfaces'),
#  ('AROA2KFNQI2VALLEGEAQL:AWSConfig-Describe',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeNetworkInterfaces'),
#  ('AROA2KFNQI2VALLEGEAQL:AWSConfig-Describe',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeNetworkInterfaces'),
#  ('AROA2KFNQI2VALLEGEAQL:AWSConfig-Describe',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeNetworkInterfaces'),
#  ('AROA2KFNQI2VALLEGEAQL:AWSConfig-Describe',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeNetworkInterfaces'),
#  ('AROA2KFNQI2VALLEGEAQL:AWSConfig-Describe',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeNetworkInterfaces'),
#  ('AROA2KFNQI2VALLEGEAQL:AWSConfig-Describe',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeNetworkInterfaces'),
#  ('AROA2KFNQI2VALLEGEAQL:AWSConfig-Describe',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeNetworkInterfaces'),
#  ('AROA2KFNQI2VALLEGEAQL:AWSConfig-Describe',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeSecurityGroups'),
#  ('AROA2KFNQI2VALLEGEAQL:AWSConfig-Describe',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeVpcs'),
#  ('AROA2KFNQI2VALLEGEAQL:AWSConfig-Describe',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeNetworkInterfaces'),
#  ('AROA2KFNQI2VALLEGEAQL:AWSConfig-Describe',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeNetworkInterfaces'),
#  ('AROA2KFNQI2VALLEGEAQL:AWSConfig-Describe',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeNetworkInterfaces'),
#  ('AROA2KFNQI2VALLEGEAQL:AWSConfig-Describe',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeNetworkInterfaces'),
#  ('AROA2KFNQI2VALLEGEAQL:AWSConfig-Describe',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeNetworkInterfaces'),
#  ('AROA2KFNQI2VALLEGEAQL:AWSConfig-Describe',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeNetworkInterfaces'),
#  ('AROA2KFNQI2VALLEGEAQL:AWSConfig-Describe',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeNetworkInterfaces'),
#  ('AROA2KFNQI2VALLEGEAQL:AWSConfig-Describe',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeNetworkInterfaces'),
#  ('AROA2KFNQI2VALLEGEAQL:AWSConfig-Describe',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeNetworkInterfaces'),
#  ('AROA2KFNQI2VALLEGEAQL:AWSConfig-Describe',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeNetworkInterfaces'),
#  ('AROA2KFNQI2VALLEGEAQL:AWSConfig-Describe',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeNetworkInterfaces'),
#  ('AROA2KFNQI2VALLEGEAQL:AWSConfig-Describe',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeNetworkInterfaces'),
#  ('AROA2KFNQI2VALLEGEAQL:AWSConfig-Describe',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeNetworkInterfaces'),
#  ('config.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/tpgt-config-service-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   'arn:aws:states:ap-southeast-2:709033477802:execution:kl-prod-bi-analy-data-extract-network_ice:14af7be9-a64e-a960-d509-5fae65753a94_144e8ea0-9ec0-6795-620f-3b32e0edf669',
#   'states.amazonaws.com',
#   'GetExecutionHistory'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DeleteNetworkInterface'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DeleteNetworkInterface'),
#  ('glue.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/kl-prod-bi-analy-data-extract-glue-extract-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('glue.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/kl-prod-bi-analy-data-extract-glue-extract-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('glue.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/kl-prod-bi-analy-data-extract-glue-extract-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DeleteNetworkInterface'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DeleteNetworkInterface'),
#  ('glue.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/kl-prod-bi-analy-data-extract-glue-extract-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('glue.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/kl-prod-bi-analy-data-extract-glue-extract-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DeleteNetworkInterface'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DeleteNetworkInterface'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DeleteNetworkInterface'),
#  ('glue.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/kl-prod-bi-analy-data-extract-glue-extract-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('glue.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/kl-prod-bi-analy-data-extract-glue-extract-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DeleteNetworkInterface'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DeleteNetworkInterface'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DeleteNetworkInterface'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DeleteNetworkInterface'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DeleteNetworkInterface'),
#  ('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   'arn:aws:states:ap-southeast-2:709033477802:execution:kl-prod-bi-analy-data-extract-network_ice:14af7be9-a64e-a960-d509-5fae65753a94_144e8ea0-9ec0-6795-620f-3b32e0edf669',
#   'states.amazonaws.com',
#   'GetExecutionHistory'),
#  ('glue.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/kl-prod-bi-analy-data-extract-glue-extract-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DeleteNetworkInterface'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DeleteNetworkInterface'),
#  ('glue.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/kl-prod-bi-analy-data-extract-glue-extract-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('glue.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/kl-prod-bi-analy-data-extract-glue-extract-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('glue.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/kl-prod-bi-analy-data-extract-glue-extract-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DeleteNetworkInterface'),
#  ('glue.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/kl-prod-bi-analy-data-extract-glue-extract-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('glue.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/kl-prod-bi-analy-data-extract-glue-extract-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('glue.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/kl-prod-bi-analy-data-extract-glue-extract-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('glue.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/kl-prod-bi-analy-data-extract-glue-extract-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('AROA2KFNQI2VLFR6ZN65C:kYAToKGjiAMchIixdScqOhjlWBHiSWPQ',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetJobRun'),
#  ('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   'arn:aws:states:ap-southeast-2:709033477802:execution:kl-prod-bi-analy-data-extract-network_ice:14af7be9-a64e-a960-d509-5fae65753a94_144e8ea0-9ec0-6795-620f-3b32e0edf669',
#   'states.amazonaws.com',
#   'GetExecutionHistory'),
#  ('logs.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/StackSet-tpgt-flowlogs-lo-FlowLogsSubscriptionRole-5QJS99X9108W',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   [],
#   'sagemaker.amazonaws.com',
#   'ListNotebookInstances'),
#  ('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   'arn:aws:states:ap-southeast-2:709033477802:execution:kl-prod-bi-analy-data-extract-network_ice:14af7be9-a64e-a960-d509-5fae65753a94_144e8ea0-9ec0-6795-620f-3b32e0edf669',
#   'states.amazonaws.com',
#   'GetExecutionHistory'),
#  ('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   'arn:aws:states:ap-southeast-2:709033477802:execution:kl-prod-bi-analy-data-extract-network_ice:14af7be9-a64e-a960-d509-5fae65753a94_144e8ea0-9ec0-6795-620f-3b32e0edf669',
#   'states.amazonaws.com',
#   'GetExecutionHistory'),
#  ('route53resolver.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/aws-service-role/route53resolver.amazonaws.com/AWSServiceRoleForRoute53Resolver',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('AROA2KFNQI2VM7OVAL3PQ:DeepSecurity',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeInstances'),
#  ('AROA2KFNQI2VM7OVAL3PQ:DeepSecurity',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeInstances'),
#  ('AROA2KFNQI2VM7OVAL3PQ:DeepSecurity',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeInstances'),
#  ('AROA2KFNQI2VM7OVAL3PQ:DeepSecurity',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeVpcs'),
#  ('AROA2KFNQI2VM7OVAL3PQ:DeepSecurity',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeInstances'),
#  ('AROA2KFNQI2VM7OVAL3PQ:DeepSecurity',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeInstances'),
#  ('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetJobRuns'),
#  ('AROA2KFNQI2VM7OVAL3PQ:DeepSecurity',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeSubnets'),
#  ('AROA2KFNQI2VM7OVAL3PQ:DeepSecurity',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeInstances'),
#  ('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   'arn:aws:states:ap-southeast-2:709033477802:execution:kl-prod-bi-analy-data-extract-network_ice:14af7be9-a64e-a960-d509-5fae65753a94_144e8ea0-9ec0-6795-620f-3b32e0edf669',
#   'states.amazonaws.com',
#   'GetExecutionHistory'),
#  ('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   'arn:aws:states:ap-southeast-2:709033477802:execution:kl-prod-bi-analy-data-extract-network_ice:14af7be9-a64e-a960-d509-5fae65753a94_144e8ea0-9ec0-6795-620f-3b32e0edf669',
#   'states.amazonaws.com',
#   'GetExecutionHistory'),
#  ('AROA2KFNQI2VOBXYK2K25:tpgt-vpc-flowlog-check',
#   'AssumedRole',
#   [],
#   'kms.amazonaws.com',
#   'Decrypt'),
#  ('lambda.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/tpgt-lambda-custom-config-role-flowlogs',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('AROA2KFNQI2VOBXYK2K25:tpgt-vpc-flowlog-check',
#   'AssumedRole',
#   [],
#   'kms.amazonaws.com',
#   'Decrypt'),
#  ('AROA2KFNQI2VLFR6ZN65C:kYAToKGjiAMchIixdScqOhjlWBHiSWPQ',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetJobRun'),
#  ('lambda.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/tpgt-lambda-custom-config-role-flowlogs',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('lambda.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/tpgt-lambda-custom-config-role-flowlogs',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('AROA2KFNQI2VOBXYK2K25:tpgt-vpc-flowlog-check',
#   'AssumedRole',
#   [],
#   'kms.amazonaws.com',
#   'Decrypt'),
#  ('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   'arn:aws:states:ap-southeast-2:709033477802:execution:kl-prod-bi-analy-data-extract-network_ice:14af7be9-a64e-a960-d509-5fae65753a94_144e8ea0-9ec0-6795-620f-3b32e0edf669',
#   'states.amazonaws.com',
#   'GetExecutionHistory'),
#  ('AROA2KFNQI2VLFR6ZN65C:kYAToKGjiAMchIixdScqOhjlWBHiSWPQ',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetJobRun'),
#  ('AROA2KFNQI2VLFR6ZN65C:kYAToKGjiAMchIixdScqOhjlWBHiSWPQ',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetJobRun'),
#  ('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetJobRuns'),
#  ('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   'arn:aws:states:ap-southeast-2:709033477802:execution:kl-prod-bi-analy-data-extract-network_ice:14af7be9-a64e-a960-d509-5fae65753a94_144e8ea0-9ec0-6795-620f-3b32e0edf669',
#   'states.amazonaws.com',
#   'GetExecutionHistory'),
#  ('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   [],
#   'sagemaker.amazonaws.com',
#   'ListNotebookInstances'),
#  ('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   'arn:aws:states:ap-southeast-2:709033477802:execution:kl-prod-bi-analy-data-extract-network_ice:14af7be9-a64e-a960-d509-5fae65753a94_144e8ea0-9ec0-6795-620f-3b32e0edf669',
#   'states.amazonaws.com',
#   'GetExecutionHistory'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DeleteNetworkInterface'),
#  ('glue.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/kl-prod-bi-analy-data-extract-glue-extract-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('glue.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/kl-prod-bi-analy-data-extract-glue-extract-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DeleteNetworkInterface'),
#  ('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   'arn:aws:states:ap-southeast-2:709033477802:execution:kl-prod-bi-analy-data-extract-network_ice:14af7be9-a64e-a960-d509-5fae65753a94_144e8ea0-9ec0-6795-620f-3b32e0edf669',
#   'states.amazonaws.com',
#   'GetExecutionHistory'),
#  ('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetJobRuns'),
#  ('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   'arn:aws:states:ap-southeast-2:709033477802:execution:kl-prod-bi-analy-data-extract-network_ice:14af7be9-a64e-a960-d509-5fae65753a94_144e8ea0-9ec0-6795-620f-3b32e0edf669',
#   'states.amazonaws.com',
#   'GetExecutionHistory'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DeleteNetworkInterface'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DeleteNetworkInterface'),
#  ('glue.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/kl-prod-bi-analy-data-extract-glue-extract-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('glue.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/kl-prod-bi-analy-data-extract-glue-extract-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DeleteNetworkInterface'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DeleteNetworkInterface'),
#  ('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   'arn:aws:states:ap-southeast-2:709033477802:execution:kl-prod-bi-analy-data-extract-network_ice:14af7be9-a64e-a960-d509-5fae65753a94_144e8ea0-9ec0-6795-620f-3b32e0edf669',
#   'states.amazonaws.com',
#   'GetExecutionHistory'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DeleteNetworkInterface'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DeleteNetworkInterface'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DeleteNetworkInterface'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DeleteNetworkInterface'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DeleteNetworkInterface'),
#  ('glue.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/kl-prod-bi-analy-data-extract-glue-extract-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DeleteNetworkInterface'),
#  ('glue.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/kl-prod-bi-analy-data-extract-glue-extract-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DeleteNetworkInterface'),
#  ('glue.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/kl-prod-bi-analy-data-extract-glue-extract-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DeleteNetworkInterface'),
#  ('glue.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/kl-prod-bi-analy-data-extract-glue-extract-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('glue.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/kl-prod-bi-analy-data-extract-glue-extract-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DeleteNetworkInterface'),
#  ('glue.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/kl-prod-bi-analy-data-extract-glue-extract-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('glue.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/kl-prod-bi-analy-data-extract-glue-extract-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('glue.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/kl-prod-bi-analy-data-extract-glue-extract-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('glue.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/kl-prod-bi-analy-data-extract-glue-extract-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('glue.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/kl-prod-bi-analy-data-extract-glue-extract-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DeleteNetworkInterface'),
#  ('glue.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/kl-prod-bi-analy-data-extract-glue-extract-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('glue.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/kl-prod-bi-analy-data-extract-glue-extract-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DeleteNetworkInterface'),
#  ('glue.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/kl-prod-bi-analy-data-extract-glue-extract-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('lambda.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/kl-prod-bi-analy-ml-pltf-lambda-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('AROA2KFNQI2VLFR6ZN65C:kYAToKGjiAMchIixdScqOhjlWBHiSWPQ',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetJobRun'),
#  ('AROA2KFNQI2VLFR6ZN65C:kYAToKGjiAMchIixdScqOhjlWBHiSWPQ',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetJobRun'),
#  ('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   'arn:aws:states:ap-southeast-2:709033477802:execution:kl-prod-bi-analy-data-extract-network_ice:14af7be9-a64e-a960-d509-5fae65753a94_144e8ea0-9ec0-6795-620f-3b32e0edf669',
#   'states.amazonaws.com',
#   'GetExecutionHistory'),
#  ('AROA2KFNQI2VLFR6ZN65C:kYAToKGjiAMchIixdScqOhjlWBHiSWPQ',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetJobRun'),
#  ('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetJobRuns'),
#  ('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   [],
#   'sagemaker.amazonaws.com',
#   'ListNotebookInstances'),
#  ('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   'arn:aws:states:ap-southeast-2:709033477802:execution:kl-prod-bi-analy-data-extract-network_ice:14af7be9-a64e-a960-d509-5fae65753a94_144e8ea0-9ec0-6795-620f-3b32e0edf669',
#   'states.amazonaws.com',
#   'GetExecutionHistory'),
#  ('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   'arn:aws:states:ap-southeast-2:709033477802:execution:kl-prod-bi-analy-data-extract-network_ice:14af7be9-a64e-a960-d509-5fae65753a94_144e8ea0-9ec0-6795-620f-3b32e0edf669',
#   'states.amazonaws.com',
#   'GetExecutionHistory'),
#  ('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   'arn:aws:states:ap-southeast-2:709033477802:execution:kl-prod-bi-analy-data-extract-network_ice:14af7be9-a64e-a960-d509-5fae65753a94_144e8ea0-9ec0-6795-620f-3b32e0edf669',
#   'states.amazonaws.com',
#   'GetExecutionHistory'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetTable'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'BatchCreatePartition'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetTable'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetDatabase'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartition'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetTable'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetTable'),
#  ('states.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/kl-prod-bi-analy-ml-pltf-stepfunction-exec-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('AROA2KFNQI2VLFR6ZN65C:kYAToKGjiAMchIixdScqOhjlWBHiSWPQ',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetJobRun'),
#  ('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   'arn:aws:states:ap-southeast-2:709033477802:execution:kl-prod-bi-analy-data-extract-network_ice:14af7be9-a64e-a960-d509-5fae65753a94_144e8ea0-9ec0-6795-620f-3b32e0edf669',
#   'states.amazonaws.com',
#   'GetExecutionHistory'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'kms.amazonaws.com',
#   'Decrypt'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'kms.amazonaws.com',
#   'Decrypt'),
#  ('AROA2KFNQI2VLFR6ZN65C:THJOIDWdxncTHxIZQwXxNeohuJUjevFk',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetJobRun'),
#  ('AROA2KFNQI2VOG7475UEI:AWSFirewallManager',
#   'AssumedRole',
#   [],
#   'config.amazonaws.com',
#   'DescribeComplianceByConfigRule'),
#  ('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   'arn:aws:states:ap-southeast-2:709033477802:execution:kl-prod-bi-analy-data-extract-network_ice:14af7be9-a64e-a960-d509-5fae65753a94_144e8ea0-9ec0-6795-620f-3b32e0edf669',
#   'states.amazonaws.com',
#   'GetExecutionHistory'),
#  ('fms.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/aws-service-role/fms.amazonaws.com/AWSServiceRoleForFMS',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('AROA2KFNQI2VOG7475UEI:AWSFirewallManager',
#   'AssumedRole',
#   [],
#   'waf-regional.amazonaws.com',
#   'GetWebACL'),
#  ('fms.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/aws-service-role/fms.amazonaws.com/AWSServiceRoleForFMS',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'kms.amazonaws.com',
#   'Decrypt'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'kms.amazonaws.com',
#   'Decrypt'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'kms.amazonaws.com',
#   'Decrypt'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'kms.amazonaws.com',
#   'Decrypt'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'kms.amazonaws.com',
#   'Decrypt'),
#  ('AROA2KFNQI2VLFR6ZN65C:THJOIDWdxncTHxIZQwXxNeohuJUjevFk',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetJobRun'),
#  ('AROA2KFNQI2VLFR6ZN65C:THJOIDWdxncTHxIZQwXxNeohuJUjevFk',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetJobRun'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'kms.amazonaws.com',
#   'Decrypt'),
#  ('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   'arn:aws:states:ap-southeast-2:709033477802:execution:kl-prod-bi-analy-data-extract-network_ice:14af7be9-a64e-a960-d509-5fae65753a94_144e8ea0-9ec0-6795-620f-3b32e0edf669',
#   'states.amazonaws.com',
#   'GetExecutionHistory'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'kms.amazonaws.com',
#   'Decrypt'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'kms.amazonaws.com',
#   'Decrypt'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'kms.amazonaws.com',
#   'Decrypt'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'kms.amazonaws.com',
#   'Decrypt'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'kms.amazonaws.com',
#   'Decrypt'),
#  ('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   [],
#   'sagemaker.amazonaws.com',
#   'ListNotebookInstances'),
#  ('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetJobRuns'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'kms.amazonaws.com',
#   'Decrypt'),
#  ('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   'arn:aws:states:ap-southeast-2:709033477802:execution:kl-prod-bi-analy-data-extract-network_ice:14af7be9-a64e-a960-d509-5fae65753a94_144e8ea0-9ec0-6795-620f-3b32e0edf669',
#   'states.amazonaws.com',
#   'GetExecutionHistory'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'kms.amazonaws.com',
#   'Decrypt'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'kms.amazonaws.com',
#   'Decrypt'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'kms.amazonaws.com',
#   'Decrypt'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'kms.amazonaws.com',
#   'Decrypt'),
#  ('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   'arn:aws:states:ap-southeast-2:709033477802:execution:kl-prod-bi-analy-data-extract-network_ice:14af7be9-a64e-a960-d509-5fae65753a94_144e8ea0-9ec0-6795-620f-3b32e0edf669',
#   'states.amazonaws.com',
#   'GetExecutionHistory'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'kms.amazonaws.com',
#   'Decrypt'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'kms.amazonaws.com',
#   'Decrypt'),
#  ('AROA2KFNQI2VIS4KBLKIC:SecurityHub-PutEvaluations',
#   'AssumedRole',
#   [],
#   'config.amazonaws.com',
#   'PutEvaluations'),
#  ('securityhub.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/aws-service-role/securityhub.amazonaws.com/AWSServiceRoleForSecurityHub',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'kms.amazonaws.com',
#   'Decrypt'),
#  ('AROA2KFNQI2VIS4KBLKIC:SecurityHub-PutEvaluations',
#   'AssumedRole',
#   [],
#   'config.amazonaws.com',
#   'PutEvaluations'),
#  ('securityhub.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/aws-service-role/securityhub.amazonaws.com/AWSServiceRoleForSecurityHub',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'kms.amazonaws.com',
#   'Decrypt'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'kms.amazonaws.com',
#   'Decrypt'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'kms.amazonaws.com',
#   'Decrypt'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'kms.amazonaws.com',
#   'Decrypt'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'kms.amazonaws.com',
#   'Decrypt'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'kms.amazonaws.com',
#   'Decrypt'),
#  ('config.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/tpgt-config-service-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   [],
#   'config.amazonaws.com',
#   'PutEvaluations'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   [],
#   'config.amazonaws.com',
#   'PutEvaluations'),
#  ('config.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/tpgt-config-service-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('config.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/tpgt-config-service-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('config.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/tpgt-config-service-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   [],
#   'config.amazonaws.com',
#   'PutEvaluations'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   [],
#   'config.amazonaws.com',
#   'PutEvaluations'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   [],
#   'config.amazonaws.com',
#   'PutEvaluations'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   [],
#   'config.amazonaws.com',
#   'PutEvaluations'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeFlowLogs'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   [],
#   'route53resolver.amazonaws.com',
#   'ListResolverQueryLogConfigAssociations'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeSecurityGroups'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   [],
#   'route53resolver.amazonaws.com',
#   'ListResolverQueryLogConfigAssociations'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   None,
#   'route53resolver.amazonaws.com',
#   'ListResolverQueryLogConfigs'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeVpcEndpoints'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeFlowLogs'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   None,
#   'route53resolver.amazonaws.com',
#   'ListResolverQueryLogConfigs'),
#  ('AROA2KFNQI2VOBXYK2K25:tpgt-vpc-flowlog-check',
#   'AssumedRole',
#   'arn:aws:iam::709033477802:role/tpgt-config-service-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeVpcs'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeVpcs'),
#  ('config.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/tpgt-config-service-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   [],
#   'config.amazonaws.com',
#   'PutEvaluations'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeVpcPeeringConnections'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   [],
#   'config.amazonaws.com',
#   'PutEvaluations'),
#  ('AROA2KFNQI2VOBXYK2K25:tpgt-vpc-flowlog-check',
#   'AssumedRole',
#   'arn:aws:iam::709033477802:role/tpgt-config-service-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeVpcs'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeVpcEndpoints'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeSecurityGroups'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeVpcs'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   [],
#   'ec2.amazonaws.com',
#   'DescribeVpcPeeringConnections'),
#  ('AROA2KFNQI2VABAX5A6Y4:StackSet-tpgt-resolverlogs-a533-VPCResolverChecker-8ozYsSdZK8Ak',
#   'AssumedRole',
#   'arn:aws:iam::709033477802:role/tpgt-config-service-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   'arn:aws:states:ap-southeast-2:709033477802:execution:kl-prod-bi-analy-data-extract-network_ice:14af7be9-a64e-a960-d509-5fae65753a94_144e8ea0-9ec0-6795-620f-3b32e0edf669',
#   'states.amazonaws.com',
#   'GetExecutionHistory'),
#  ('AROA2KFNQI2VABAX5A6Y4:StackSet-tpgt-resolverlogs-a533-VPCResolverChecker-8ozYsSdZK8Ak',
#   'AssumedRole',
#   'arn:aws:iam::709033477802:role/tpgt-config-service-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('config.amazonaws.com',
#   'AWSService',
#   'arn:aws:iam::709033477802:role/tpgt-config-service-role',
#   'sts.amazonaws.com',
#   'AssumeRole'),
#  ('AROA2KFNQI2VALLEGEAQL:configLambdaExecution',
#   'AssumedRole',
#   [],
#   'config.amazonaws.com',
#   'PutEvaluations'),
#  ('config.amazonaws.com',
#   'AWSService',
# ...
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetTable'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetConnection'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetTable'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetConnection'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetConnection'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetTable'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetDatabase'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetConnection'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetConnection'),
#  ('AROA2KFNQI2VJ2RJJK6SI:jiaxi.li@vodafone.com.au',
#   'AssumedRole',
#   'arn:aws:states:ap-southeast-2:709033477802:execution:kl-prod-bi-analy-data-extract-network_ice:14af7be9-a64e-a960-d509-5fae65753a94_144e8ea0-9ec0-6795-620f-3b32e0edf669',
#   'states.amazonaws.com',
#   'GetExecutionHistory'),
#  ('AROA2KFNQI2VMKNOM2TOA:vpc-flow-logging+709033477802',
#   'AssumedRole',
#   [],
#   'logs.amazonaws.com',
#   'CreateLogStream'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetConnection'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetConnection'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetConnection'),
#  ('AROA2KFNQI2VOY3YQEN5B:vpc-flow-logging+709033477802',
#   'AssumedRole',
#   [],
#   'logs.amazonaws.com',
#   'CreateLogStream'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetTable'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetDatabase'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetTable'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetDatabase'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetTable'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetTable'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetConnection'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetTable'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetTable'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VOY3YQEN5B:vpc-flow-logging+709033477802',
#   'AssumedRole',
#   [],
#   'logs.amazonaws.com',
#   'CreateLogStream'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetTable'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VMKNOM2TOA:vpc-flow-logging+709033477802',
#   'AssumedRole',
#   [],
#   'logs.amazonaws.com',
#   'CreateLogStream'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetDatabase'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VMKNOM2TOA:vpc-flow-logging+709033477802',
#   'AssumedRole',
#   [],
#   'logs.amazonaws.com',
#   'CreateLogStream'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetTable'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetTable'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetConnection'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VOY3YQEN5B:vpc-flow-logging+709033477802',
#   'AssumedRole',
#   [],
#   'logs.amazonaws.com',
#   'CreateLogStream'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetDatabase'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetDatabase'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetTable'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetTable'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetTable'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetDatabase'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetTable'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetTable'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetTable'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetTable'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetConnection'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetDatabase'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetDatabase'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetConnection'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ('AROA2KFNQI2VHXCDF22NX:GlueJobRunnerSession',
#   'AssumedRole',
#   [],
#   'glue.amazonaws.com',
#   'GetPartitions'),
#  ...]
