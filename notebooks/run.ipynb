# %%
 # !docker run \
   -v /Users/jl102430/Documents/study/code_repo/my_anomaly_detection/baseline/sbustreamspot-core:/app \
   -v /Users/jl102430/Documents/study/code_repo/my_anomaly_detection/baseline/sbustreamspot-data:/data \
   -v /Users/jl102430/Documents/study/code_repo/my_anomaly_detection/baseline/streamspot-bootstrap-clusters:/data/bootstrap \
   streamspot \
   /app/streamspot --edges=/app/test_edges.txt \
              --bootstrap=/app/test_bootstrap_clusters.txt \
              --chunk-length=10 \
              --num-parallel-graphs=10 \
              --max-num-edges=10 \
              --dataset=all
# Out:
# StreamSpot (C=10, L=1000, N=10, P=10, DATA=all)
# Bootstrap Cluster 0: 0
# Bootstrap Cluster 1: 1
# global_threshold: 0.6
# Training Graphs:
#  1 0
# Reading edges from: /app/test_edges.txt
# Dropped edges: 0
# Train edges: 5
# Test edges: 7
# +++ Print Groups
# 3 2
# Constructing 2 training graphs:
# 64-bit random numbers:
# 6970346519555663902 11560441128271141205 16171751228844912391 5879470548609617213 1279354321334578298 2054987395126245525 2030543341655775190 14470024916368229194 18256352953092035904 7786727758199607406 8643270319842211823 9660473348965699881
# 13731858464338422518 5801452423776861019 7318966916716686451 44942661657747502 13529743537421068437 2243490271074131831 11250134312153740039 13832224484866474133 10088334833715812837 2218376551463741524 3750002215728358728 3972391395990096074
# ...

# %%
# build
# !docker run \
   -v /Users/jl102430/Documents/study/code_repo/my_anomaly_detection/baseline/sbustreamspot-core:/app \
   streamspot bash -c "cd /app; make clean optimized"

# %%
# sample gfc data
# !docker run \
  -v /Users/jl102430/Documents/study/code_repo/my_anomaly_detection/baseline/sbustreamspot-core:/app \
  -v /Users/jl102430/Documents/study/code_repo/my_anomaly_detection/baseline/sbustreamspot-data:/data \
  -v /Users/jl102430/Documents/study/code_repo/my_anomaly_detection/baseline/streamspot-bootstrap-clusters:/data/bootstrap \
  streamspot \
  /app/streamspot --edges=/data/all.tsv \
             --bootstrap=/data/bootstrap/03-C50_k10_gfc_noise10.txt \
             --chunk-length=50 \
             --num-parallel-graphs=10 \
             --max-num-edges=100 \
             --dataset=gfc

# %%
# sample ydc data
# !docker run \
  -v /Users/jl102430/Documents/study/code_repo/my_anomaly_detection/baseline/sbustreamspot-core:/app \
  -v /Users/jl102430/Documents/study/code_repo/my_anomaly_detection/baseline/sbustreamspot-data:/data \
  -v /Users/jl102430/Documents/study/code_repo/my_anomaly_detection/baseline/streamspot-bootstrap-clusters:/data/bootstrap \
  streamspot \
  /app/streamspot --edges=/data/all.tsv \
             --bootstrap=/data/bootstrap/02-C25_k5_ydc.txt \
             --chunk-length=25 \
             --num-parallel-graphs=10 \
             --max-num-edges=100 \
             --dataset=ydc

# %% [markdown]
# ### In Sagemaker

# %%
# !docker load < streamspot_docker_export.tar.gz

# !docker run \
   -v /home/ec2-user/SageMaker/anomaly_detection/my_anomaly_detection/baseline/sbustreamspot-core:/app \
   streamspot bash -c "cd /app; make clean optimized"
    

# !docker run \
  -v /home/ec2-user/SageMaker/anomaly_detection/my_anomaly_detection/baseline/sbustreamspot-core:/app \
  -v /home/ec2-user/SageMaker/anomaly_detection/my_anomaly_detection/baseline/sbustreamspot-data:/data \
  -v /home/ec2-user/SageMaker/anomaly_detection/my_anomaly_detection/baseline/streamspot-bootstrap-clusters:/data/bootstrap \
  streamspot \
  /app/streamspot --edges=/data/all.tsv \
             --bootstrap=/data/bootstrap/01-C50_k10_all.txt \
             --chunk-length=50 \
             --num-parallel-graphs=10 \
             --max-num-edges=100 \
             --dataset=all

# !docker run \
  -v /home/ec2-user/SageMaker/anomaly_detection/my_anomaly_detection/baseline/sbustreamspot-core:/app \
  -v /home/ec2-user/SageMaker/anomaly_detection/my_anomaly_detection/baseline/sbustreamspot-data:/data \
  -v /home/ec2-user/SageMaker/anomaly_detection/my_anomaly_detection/baseline/streamspot-bootstrap-clusters:/data/bootstrap \
  streamspot \
  /app/streamspot --edges=/data/all.tsv \
             --bootstrap=/data/bootstrap/02-C25_k5_ydc.txt \
             --chunk-length=25 \
             --num-parallel-graphs=10 \
             --max-num-edges=100 \
             --dataset=ydc

# !docker run \
  -v /home/ec2-user/SageMaker/anomaly_detection/my_anomaly_detection/baseline/sbustreamspot-core:/app \
  -v /home/ec2-user/SageMaker/anomaly_detection/my_anomaly_detection/baseline/sbustreamspot-data:/data \
  -v /home/ec2-user/SageMaker/anomaly_detection/my_anomaly_detection/baseline/streamspot-bootstrap-clusters:/data/bootstrap \
  streamspot \
  /app/streamspot --edges=/data/all.tsv \
             --bootstrap=/data/bootstrap/03-C50_k10_gfc.txt \
             --chunk-length=50 \
             --num-parallel-graphs=10 \
             --max-num-edges=10000 \
             --dataset=gfc > ../log.txt 2>&1

# %% [markdown]
# ### reduced attack num in test

# %%
# %sh

docker run \
  -v /home/ec2-user/SageMaker/anomaly_detection/my_anomaly_detection/baseline/sbustreamspot-core:/app \
  -v /home/ec2-user/SageMaker/anomaly_detection/my_anomaly_detection/baseline/sbustreamspot-data:/data \
  -v /home/ec2-user/SageMaker/anomaly_detection/my_anomaly_detection/baseline/streamspot-bootstrap-clusters:/data/bootstrap \
  streamspot \
  /app/streamspot --edges=/data/all.tsv \
             --bootstrap=/data/bootstrap/03-C50_k10_gfc.txt \
             --chunk-length=50 \
             --num-parallel-graphs=10 \
             --max-num-edges=10000 \
             --dataset=gfc \
             --attack-pct=100 > ../log1.txt 2>&1

# %% [markdown]
# ### adding noise in training

# %%
# %%sh
# for noise in {25..45..5}
# do
#     echo "############# Noise Percentage: $noise ################"
#     docker run \
#   -v /home/ec2-user/SageMaker/anomaly_detection/my_anomaly_detection/baseline/sbustreamspot-core:/app \
#   -v /home/ec2-user/SageMaker/anomaly_detection/my_anomaly_detection/baseline/sbustreamspot-data:/data \
#   -v /home/ec2-user/SageMaker/anomaly_detection/my_anomaly_detection/baseline/streamspot-bootstrap-clusters:/data/bootstrap \
#   streamspot \
#   /app/streamspot --edges=/data/all.tsv \
#              --bootstrap=/data/bootstrap/03-C50_k10_gfc_noise$noise.txt \
#              --chunk-length=50 \
#              --num-parallel-graphs=10 \
#              --max-num-edges=10000 \
#              --dataset=gfc \
#              --noise-pct=$noise > ../log.txt 2>&1
# done

# %% [markdown]
# ### noise + test attack

# %%
#Run Container
docker run -it -d \
      -v /home/ec2-user/SageMaker/anomaly_detection/my_anomaly_detection/baseline/sbustreamspot-core:/app \
      -v /home/ec2-user/SageMaker/anomaly_detection/my_anomaly_detection/baseline/sbustreamspot-data:/data \
      -v /home/ec2-user/SageMaker/anomaly_detection/my_anomaly_detection/baseline/streamspot-bootstrap-clusters:/data/bootstrap \
      streamspot

# %%
# Build
docker exec -it \
    94ec2f02e280 \
    bash -c "cd /app; make clean optimized"

# %%
# Run
for noise in {0..50..10}
do
    for attack in {0..50..10}
    do
        echo "############# Num Noise: $noise ################"
        echo "############ Num Attack: $attack ###############"
        docker exec -it \
          94ec2f02e280 \
          /app/streamspot --edges=/data/all.tsv \
                     --bootstrap=/data/bootstrap/03-C50_k10_gfc_noise$noise.txt \
                     --chunk-length=50 \
                     --num-parallel-graphs=200 \
                     --max-num-edges=10000 \
                     --dataset=gfc \
                     --num-noise=$noise \
                     --num-test-attack=$attack > ../log.txt 2>&1
    done
done

# %%
docker exec -it \
          94ec2f02e280 \
          /app/streamspot --edges=/data/all.tsv \
                     --bootstrap=/data/bootstrap/03-C50_k10_gfc_noise0.txt \
                     --chunk-length=50 \
                     --num-parallel-graphs=200 \
                     --max-num-edges=10000 \
                     --dataset=gfc \
                     --num-noise=0 \
                     --num-test-attack=50 > ../log.txt 2>&1

# %%
# docker exec -it \
#       06a80c38b2a7 \
#       /app/streamspot --edges=/data/all.tsv \
#                  --bootstrap=/data/bootstrap/03-C50_k10_gfc_noise10.txt \
#                  --chunk-length=50 \
#                  --num-parallel-graphs=1 \
#                  --max-num-edges=10000 \
#                  --dataset=gfc \
#                  --num-noise=10 \
#                  --num-test-attack=10 > ../log.txt 2>&1

# %%
# docker exec -it \
#       -v /home/ec2-user/SageMaker/anomaly_detection/my_anomaly_detection/baseline/sbustreamspot-core:/app \
#       -v /home/ec2-user/SageMaker/anomaly_detection/my_anomaly_detection/baseline/sbustreamspot-data:/data \
#       -v /home/ec2-user/SageMaker/anomaly_detection/my_anomaly_detection/baseline/streamspot-bootstrap-clusters:/data/bootstrap \
#       830ebd0cf087 \
#       /app/streamspot --edges=/data/all.tsv \
#                  --bootstrap=/data/bootstrap/03-C50_k10_gfc_noise10.txt \
#                  --chunk-length=50 \
#                  --num-parallel-graphs=10 \
#                  --max-num-edges=10000 \
#                  --dataset=gfc \
#                  --num-noise=10 \
#                  --num-test-attack=10 > ../log.txt 2>&1

# %%
# !docker run \
  -v /Users/jl102430/Documents/study/code_repo/my_anomaly_detection/baseline/sbustreamspot-core:/app \
  -v /Users/jl102430/Documents/study/code_repo/my_anomaly_detection/baseline/sbustreamspot-data:/data \
  -v /Users/jl102430/Documents/study/code_repo/my_anomaly_detection/baseline/streamspot-bootstrap-clusters:/data/bootstrap \
#   -v /Users/jl102430/Documents/study/code_repo/my_anomaly_detection/data:/data \
  streamspot \
  /app/streamspot --edges=/data/sample_edges.tsv \
             --bootstrap=/data/custom_bootstrap.txt \
             --chunk-length=500 \
             --num-parallel-graphs=10 \
             --max-num-edges=10 \
             --dataset=all
# Out:
# StreamSpot (C=100, L=1000, N=10, P=10, DATA=all)
# Bootstrap Cluster 0: 71 72
# Bootstrap Cluster 1: 47 62
# global_threshold: 0.6
# Training Graphs:
#  62 47 72 71
# Reading edges from: /data/data_edges.tsv
# Dropped edges: 0
# Train edges: 3697
# Test edges: 25293
# +++ Print Groups
# 287 117 116 97 189 167 151 443 419 288
# 436 14 109 354 353 226 466 330 454 140
# 130 92 53 282 127 318 446 395 231 30
# 0 296 142 180 433 148 273 255 166 107
# 103 301 304 339 64 9 35 400 74 186
# 413 98 190 379 398 205 133 421 412 100
# 438 183 347 315 253 42 152 193 387 16
# 250 90 215 125 111 101 372 303 120 172
# 274 448 456 360 224 131 230 321 345 7
# 75 52 41 368 36 291 57 243 136 204
# 389 457 333 460 88 275 300 95 3 223
# 306 207 187 468 452 357 144 316 146 423
# 324 422 112 15 37 380 312 96 106 85
# 23 365 225 261 170 390 33 89 150 409
# 54 346 246 216 11 341 56 94 397 325
# 344 263 260 289 68 161 405 249 424 352
# 1 450 13 406 18 220 408 234 50 432
# 238 235 463 363 118 129 147 351 451 202
# ...

# %%
# On SageMaker
# !docker run \
  -v /home/ec2-user/SageMaker/my_anomaly_detection/baseline/sbustreamspot-core:/app \
  -v /home/ec2-user/SageMaker/my_anomaly_detection/data:/data \
  streamspot \
  /app/streamspot --edges=/data/sample_edges.tsv \
             --bootstrap=/data/custom_bootstrap.txt \
             --chunk-length=512 \
             --num-parallel-graphs=10 \
             --max-num-edges=10 \
             --dataset=all


        
# !docker run \
  -v /home/ec2-user/SageMaker/my_anomaly_detection/baseline/sbustreamspot-core:/app \
  streamspot bash -c "cd /app; make clean debug"

# %% [markdown]
# ## Python

# %%
# !python main.py --edges ../../baseline/sbustreamspot-data/all.tsv \
--bootstrap ../../baseline/streamspot-bootstrap-clusters/01-C50_k10_all.txt \
--chunk-length 10 \
--num-parallel-graphs 10 \
--max-num-edges 10
